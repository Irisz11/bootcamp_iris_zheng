# %% [markdown]
# # Environment & Config Check
#
# This notebook verifies that the project environment, `.env` configuration, and NumPy installation are working correctly.

# %%
from dotenv import load_dotenv
import os

load_dotenv("../.env")

print("API_KEY present:", os.getenv("API_KEY") is not None)
print("DATA_DIR:", os.getenv("DATA_DIR"))
# Out:
# API_KEY present: True
# DATA_DIR: ./data

# %%
import numpy as np

arr = np.array([2, 4, 6])

print("Array:", arr)
print("Mean:", arr.mean())
print("Vectorized x10:", arr * 10)
# Out:
# Array: [2 4 6]
# Mean: 4.0
# Vectorized x10: [20 40 60]
